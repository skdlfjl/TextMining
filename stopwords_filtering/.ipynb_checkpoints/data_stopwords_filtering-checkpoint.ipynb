# %%
# 파이썬개발자[6] 데이터엔지니어[7] 데이터사이언티스트[12] 머신러닝엔지니어[13] 빅데이터엔지니어[15]
category = [6, 7, 12, 13, 15]

# %%
# 각 카테고리의 데이터 개수(채용공고의 개수)를 가져와서 튜플형태로 저장한 뒤, 리스트에 넣는다

category_len = []
for category_num in category:
    data = open('../category{0}.txt'.format(category_num), 'r', encoding = 'utf-8')
    lines = data.readlines()  # 데이터 불러와서 line 단위로 넣는다
    #print(len(lines))
    tu = category_num, len(lines)
    category_len.append(tu)

# %%
category_len # ( 카테고리번호, 크롤링 데이터 개수 ) 모양의 튜플
# Out:
# [(6, 243), (7, 210), (12, 144), (13, 143), (15, 114)]

# %%
## 1.
from konlpy.tag import Hannanum
hannanum = Hannanum()

## 2.
stopwords_ko = open('stopwords_ko.txt', 'r', encoding='utf-8')
stopwords_ko = stopwords_ko.readlines()
for i in range(len(stopwords_ko)):
    stopwords_ko[i] = stopwords_ko[i].replace('\n', '')
#print(stopwords_ko)

## 3.
import nltk
#nltk.download('stopwords')
stopwords_en = nltk.corpus.stopwords.words('english')
#print(len(stopwords_en), stopwords_en, '\n')

# %%
for category_num, data_num in category_len:
    
    data = open('../data_cleansing_final/cleansing_category{0}_list{1}.txt'.format(category_num, data_num), 'r', encoding = 'utf-8')
    data = data.readlines()  # 데이터 불러와서 line 단위로 넣는다
    print('#', category_num, '번 카테고리의 크롤링한 채용공고의 개수 = ', len(data))
    
    for i in range(len(data)):
        data[i] = data[i].replace('\n', '')    # 각 문장마다 들어있는 줄바꿈 기호 없애주기
    
    token_list = []
    for i in data: 
        token_list.append(hannanum.morphs(i))  # 리스트 안에 크롤링한 채용공고 개수만큼의 토큰 리스트들이 들어있음
    tokens = sum(token_list, [])               # 이중리스트 해제, 카테고리의 전체 토큰이 저장되어 있습니다.
    
    
    ## 1. pos태깅을 이용한 stopwords 제거
    # 주요 태그 N(체언)과 F(외국어)를 제외한 나머지 단어들을 제거해준다.
    token_pos_list = []
    for i in data:
        token_pos_list.append(hannanum.pos(i)) # 리스트 안에 크롤링한 채용공고 개수만큼의 토큰 리스트들이 들어있음
    tokens_pos = sum(token_pos_list, [])       # 이중리스트 해제, 카테고리의 pos태깅된 전체 토큰이 저장되어 있습니다.
    
    k_tokens = []  # k_tokens에 제거 완료된 토큰을 넣습니다
    pos_stopwords = []
    for i in range(len(tokens_pos)):
        if tokens_pos[i][1] == 'N' or tokens_pos[i][1] == 'F':
            k_tokens.append(tokens[i])
        else:
            pos_stopwords.append(tokens[i])
            
    test = set(pos_stopwords)
    print(len(tokens), '->', len(k_tokens))
    print('#postag를 이용해 불용어를 삭제한 tokens :', test)  # 혹시 모르니까 뭐가 지워졌는지 확인해보기
    
    
    ## 2. 한국어 stopwords 리스트 불러와서 제거
    # 위에서 미리 불러와서 저장해둔 stopwords_ko를 사용한다
    kk_tokens = [w for w in k_tokens if w not in stopwords_ko]   # kk_tokens에 제거 완료된 토큰을 넣습니다
    
    
    ## 3. 영어 stopwords 제거
    # 위에서 미리 불용어 목록 얻음 (소문자화 된 점에 유의)
    k_e_tokens = [w for w in kk_tokens if w.lower() not in stopwords_en]
    # lower()를 이용해서 임시로 소문자화 한 뒤 필터링 한 단어(토큰)들을 k_e_tokens변수에 저장
    
    
    ## 4. 1글자 단어 제거(영어는 제외한다) - 1글자 stopwords 리스트 생성
    # 저장하지 않고 각 카테고리에서 그때그때 만들어 쓴다
    one_word = []  
    for i in k_e_tokens:
        if len(i) == 1:
            #print(i)
            one_word.append(i)  # 1글자 토큰을 one_word 리스트에 저장한다        
    u = set(one_word)  # 유니크 워드만 뽑기
    
    stopwords_one = []
    for i in u:
        if ord('a') <= ord(i.lower()) <= ord('z'):
            print(i)
        else:
            stopwords_one.append(i)
    print(stopwords_one) # 영어를 제외한 1글자 stopwords 리스트 stopwords_one

    final_tokens = [w for w in k_e_tokens if w not in stopwords_one]
    # 필터링 한 단어(토큰)들을 final_tokens변수에 저장
    
    
    ## 전부 소문자로 바꿔서 low_tokens변수에 저장하자
    low_tokens = []
    for i in range(len(final_tokens)):
        low_tokens.append(final_tokens[i].lower())

        
    ## stopwords 제거 완료한 빈도수 추출해보기
    fdistPlain_low = nltk.FreqDist(low_tokens)
    print(fdistPlain_low.most_common(30))  # 빈도수가 높은 토큰 30개 추출
    
    
    ## 각 변수에 저장하자
    print('#최종 token개수: ', len(low_tokens), '\n')
    globals()['tokens{}'.format(category_num)] = low_tokens
# Out:
# # 6 번 카테고리의 크롤링한 채용공고의 개수 =  243
# 27104 -> 16454
# #postag를 이용해 불용어를 삭제한 tokens : {'멀', '졸', '직접', '키우', '날카롭', '어', '혹은', '들이', '뛰', '받', '관계없이', '임하', '이내', '급', '거리낌없이', '신나', '듣', '상관없이', '쉽', '와도', '글쓰', '이러하', '한하', '다면', '오히려', '꼼꼼하', '깊이있', '얼마나', '갖추', '즐겁', '는지', '남다르', '시ㅁ', '며', '제대로', '이렇', '·', '시ㄹ', '어서ㄴ', '만', '끊이', '가르치', '다는', '관하', '통하', '셨나', '고자', '쓰', 'ㄴ데', '바꾸', '일', '서로', '이루', '에', '보다는', '그외', '에도', '특히', '대하', '보', '으면', '발맞추', '계속', '시ㄴ', '불', '추후', '그렇', '달리', '원하', '매우', '리', '또한', '높', '와의', '각', '에서의', '으시면', '좋', '개', '아아', '계시', 'ㄹ', '두렵', '지만', '를', '알리', '함께하', '아낌없이', '조금', '모두', '인하', '보다', '잘', '서는', '도', '몰리', '는', '작', '버리', '맞', '아니', '으시거나', '과는', '거나', '부터', 'ㅂ니다', 'ㄴ다', '폭넓', '독하', '시는', '새롭', '로부터', '옳', '원활히', '별로', '으면서', '겠어', '꼭', '특별히', '로', '면서', '없', '므로', '높이', '롭', '려고', '오', '대회', '맞추', '일으키', '로는', '냐', '되', '수많', '대', '배우', '으시어야', '드리', '하고', '깊', '단', '현재', '서의', '시거나', '절', '그치', '어렵', '에서', '실은', '면', '연락드리', 'ㄴ', '과', '라', '으로서', '서', '보이', '모든', '또는', '있', '다른', '이런', '사', '이상', '크', '나타내', '부탁드리', '준하', '에게', '망설이', '넘치', '내', '선', '었습니다', '싶', '빠르', '뜨겁', '바라', '시고', '많', '즐기', '꾸준히', '흩어지', '화하', '맡', '처럼', '어야', '더어', '따르', '미치', '까다롭', '가장', '찾', '자', '같', '과의', '어
서ㄴ', '물', '만', '가르치', '다는', '스스로', '지', '관하', '및', '통하', '밝', '이나', '적어도', '되', '시키', '가', '대', '배우', '짜', '먼저', '겠다는', '고', '드리', '습니다', '쓰', '피', '하고', '바꾸', 'ㄴ데', '함께', '깊', '고자', '일', '단순히', '단', '이루', '석', '다루', '시거나', '그치', '하', '어렵', '에', '어울리', '서이', '에서', '스럽', '타', '실은', '면', '연락드리', '비', '특히', '건', '예의바르', 'ㄴ', '과', '더라도', '겪', '아', '대하', '보', '도록', '라', '이', '어느', '으면', 'ㄴ단', '이끌', '더', '었던', '발맞추', '서', '총', '만의', '시ㄴ', '에게는', '불', '모든', '까지', '정하', '으로', '끊임없이', '들', '실제로', '살피', '또는', '기', '나', '헤치', '있', '다른', '매우', '지니', '그', '정말', '흐르', '은', '을', '주', '높', '강하', '와의', '읽', '사', '만들', '가지', '이상', '크', '어도', '각', '으니', '준하', '에게'}
# W
# c
# B
# R
# C
# ['위', '소', '3', '두', '팀', '줄', '2', '+', '쉘', '웹', '문', '식', '개', '내', '지', '강', '딥', '⅓', '직', '학', '삶', '빅', '툴', '정', '대', '앱', '전', '적', '유', '쪽', '후', '바', '\u200b', '기', '한', '데', '외', '글', '간', '리', '호', '분', '수', '석', '주', '도', '1', '근', '중', '시', '미', '끝', '평', '성', '요', '뿐']
# [('경험', 464), ('개발', 211), ('관련', 190), ('데이터', 159), ('분석', 116), ('python', 101), ('이해', 96), ('능력', 89), ('활용', 89), ('경력', 83), ('사용', 82), ('딥러닝', 81), ('머신러닝', 81), ('경험자', 67), ('분야', 66), ('learning', 63), ('기반', 62), ('tensorflow', 61), ('서비스', 60), ('논문', 55), ('기술', 54), ('언어', 54), ('구현', 49), ('지식', 48), ('알고리즘', 47), ('pytorch', 45), ('가능', 45), ('ml', 43), ('프로그래밍', 42), ('업무', 40)]
# #최종 token개수:  8049
#
# # 15 번 카테고리의 크롤링한 채용공고의 개수 =  114
# 11365 -> 7207
# #postag를 이용해 불용어를 삭제한 tokens : {'기이', '으시는', '에서의', '멀', '직접', '좋', '개', '내', '어', '혹은', '로서', '의', '선', '계시', 'ㄹ', '뛰', '싶', '만나', '빠르', '바라', '를', '시고', '많', '함께하', '아낌없이', '즐기', '음', '예', '익히', '모두', '와', '잘', '꾸준히', '화하', '맡', '임하', '도', '아우르', '는', '어야', '상하', '게', '으시ㄴ', '요하', '맞', '아니', '으시거나', '갖', '거나', 'ㅂ니다', '위하', '않', '폭넓', '쉽', '시는', '새롭', '로부터', '원활히', '넘나들', '찾', '자', '한하', '같', '늘', '알', 'ㅁ', '꼼꼼하', 'ㄴ다는', '로', '갖추', '면서', '과의', '즐겁', '없', '어서', '롭', '려고', '느끼', '며', '시', '오', '으며', '대회', '시ㄹ', '여러', '려', '물', '만', '어서ㄴ', '스스로', '지', '및', '통하', '이나', '되', '아거나', '시키', '가', '었는지', '안', '대', '배우', '고', '습니다', '고자', '피', '하고', 'ㄴ데', '함께', '깊', '쓰', '다', '서로', '히', '석', '서의', '서와의', '다루', '하', '어렵', '재미있', '에', '에서', '스럽', '타', '면', '비', '예의바르', 'ㄴ', '과', '겪', '아', '대하', '보', '배', '으시다면', '라', '이', '으면', '어느', 'ㄴ단', '이끌', '더', '었던', '발맞추', '총', '서', '이르', '왜', '시ㄴ', '에게는', '항상', '모든', '까지', '그렇', '셨거나', '으로', '끊임없이', '들', '실제로', '살피', '또는', '기', '나', '있', '려는', '간', '열리', '리', '지니', '그', '걸치', '흐르', '은', '을', '주', '높', '강하', '와의', '읽', '가지', '사', '만들', '이상', '어도', '각', '준하', '에게'}
# W
# B
# R
# C
# ['위', '소', '3', '두', '팀', '+', '2', '쉘', '웹', '문', '식', '개', '내', '딥', '⅓', '직', '학', '툴', '대', '부', '전', '적', '\u200b', '한', '외', '데', '간', '리', '분', '속', '수', '주', '4', '1', '중', '미', '시', '끝', '처', '성', '뿐']
# [('경험', 375), ('데이터', 157), ('개발', 125), ('관련', 115), ('분석', 94), ('경력', 82), ('운영', 71), ('활용', 70), ('이해', 63), ('능력', 63), ('python', 60), ('기반', 59), ('사용', 51), ('서비스', 51), ('보유', 49), ('처리', 49), ('가능', 45), ('구축', 44), ('업무', 44), ('지식', 43), ('경험자', 41), ('딥러닝', 40), ('환경', 40), ('aws', 37), ('우대', 37), ('머신러닝', 36), ('시스템', 36), ('기술', 35), ('언어', 34), ('역량', 34)]
# #최종 token개수:  6254

# %%
# tokens6, tokens7, tokens12, tokens13, tokens15에 각 category의 token들이 저장되어 있습니다.

# %%
# 빈도수 top10 찍어보기
print('toekns6 :', nltk.FreqDist(tokens6).most_common(10), '\n')
print('toekns7 :', nltk.FreqDist(tokens7).most_common(10), '\n')
print('toekns12 :', nltk.FreqDist(tokens12).most_common(10), '\n')
print('toekns13 :', nltk.FreqDist(tokens13).most_common(10), '\n')
print('toekns15 :', nltk.FreqDist(tokens15).most_common(10), '\n')
# Out:
# toekns6 : [('경험', 1016), ('개발', 565), ('이해', 226), ('python', 212), ('서비스', 208), ('사용', 191), ('운영', 175), ('관련', 140), ('경력', 137), ('활용', 130)]
#
# toekns7 : [('경험', 786), ('데이터', 338), ('개발', 315), ('운영', 233), ('이해', 143), ('분석', 133), ('관련', 132), ('경력', 123), ('구축', 120), ('능력', 120)]
#
# toekns12 : [('경험', 447), ('데이터', 271), ('분석', 188), ('관련', 165), ('개발', 139), ('활용', 120), ('능력', 112), ('경력', 110), ('이해', 103), ('python', 86)]
#
# toekns13 : [('경험', 464), ('개발', 211), ('관련', 190), ('데이터', 159), ('분석', 116), ('python', 101), ('이해', 96), ('능력', 89), ('활용', 89), ('경력', 83)]
#
# toekns15 : [('경험', 375), ('데이터', 157), ('개발', 125), ('관련', 115), ('분석', 94), ('경력', 82), ('운영', 71), ('활용', 70), ('이해', 63), ('능력', 63)]

# %%
len(tokens6)
# Out:
# 14047

# %%
## txt파일로 tokens6,7,12,13,15 저장 (임시입니다, 변경될 수 있습니다)

line = '\n'.join(tokens6) 

f = open('tokens6.txt', 'w')
f.write(line)
f.close()

# %%
## 저장되는거 확인했으니 for문을 이용해 모든 tokens변수들을 저장해줍시다 (임시입니다, 변경될 수 있습니다)

for i in category:
    tokens = globals()['tokens{}'.format(i)]
    line = '\n'.join(tokens)
    
    f = open('tokens{}.txt'.format(i), 'w')
    f.write(line)
    f.close()
