# %%
# 파이썬개발자[6] 데이터엔지니어[7] 데이터사이언티스트[12] 머신러닝엔지니어[13] 빅데이터엔지니어[15]
category = [6, 7, 12, 13, 15]

# %%
# 각 카테고리의 데이터 개수(채용공고의 개수)를 가져와서 튜플형태로 저장한 뒤, 리스트에 넣는다

category_len = []
for category_num in category:
    data = open('../category{0}.txt'.format(category_num), 'r', encoding = 'utf-8')
    lines = data.readlines()  # 데이터 불러와서 line 단위로 넣는다
    #print(len(lines))
    tu = category_num, len(lines)
    category_len.append(tu)

# %%
category_len # ( 카테고리번호, 크롤링 데이터 개수 ) 모양의 튜플
# Out:
# [(6, 243), (7, 210), (12, 144), (13, 143), (15, 114)]

# %%
## 1.
from konlpy.tag import Hannanum
hannanum = Hannanum()

## 2.
stopwords_ko = open('stopwords_ko.txt', 'r', encoding='utf-8')
stopwords_ko = stopwords_ko.readlines()
for i in range(len(stopwords_ko)):
    stopwords_ko[i] = stopwords_ko[i].replace('\n', '')
#print(stopwords_ko)

## 3.
import nltk
#nltk.download('stopwords')
stopwords_en = nltk.corpus.stopwords.words('english')
#print(len(stopwords_en), stopwords_en, '\n')

# %%
for category_num, data_num in category_len:
    
    data = open('../data_cleansing_final/cleansing_category{0}_list{1}.txt'.format(category_num, data_num), 'r', encoding = 'utf-8')
    data = data.readlines()  # 데이터 불러와서 line 단위로 넣는다
    print('#', category_num, '번 카테고리의 크롤링한 채용공고의 개수 = ', len(data))
    
    for i in range(len(data)):
        data[i] = data[i].replace('\n', '')    # 각 문장마다 들어있는 줄바꿈 기호 없애주기
    
    token_list = []
    for i in data: 
        token_list.append(hannanum.morphs(i))  # 리스트 안에 크롤링한 채용공고 개수만큼의 토큰 리스트들이 들어있음
    tokens = sum(token_list, [])               # 이중리스트 해제, 카테고리의 전체 토큰이 저장되어 있습니다.
    
    
    ## 1. pos태깅을 이용한 stopwords 제거
    # 주요 태그 N(체언)과 F(외국어)를 제외한 나머지 단어들을 제거해준다.
    token_pos_list = []
    for i in data:
        token_pos_list.append(hannanum.pos(i)) # 리스트 안에 크롤링한 채용공고 개수만큼의 토큰 리스트들이 들어있음
    tokens_pos = sum(token_pos_list, [])       # 이중리스트 해제, 카테고리의 pos태깅된 전체 토큰이 저장되어 있습니다.
    
    k_tokens = []  # k_tokens에 제거 완료된 토큰을 넣습니다
    pos_stopwords = []
    for i in range(len(tokens_pos)):
        if tokens_pos[i][1] == 'N' or tokens_pos[i][1] == 'F':
            k_tokens.append(tokens[i])
        else:
            pos_stopwords.append(tokens[i])
            
    test = set(pos_stopwords)
    print(len(tokens), '->', len(k_tokens))
    print('#postag를 이용해 불용어를 삭제한 tokens :', test)  # 혹시 모르니까 뭐가 지워졌는지 확인해보기
    
    
    ## 2. 한국어 stopwords 리스트 불러와서 제거
    # 위에서 미리 불러와서 저장해둔 stopwords_ko를 사용한다
    kk_tokens = [w for w in k_tokens if w not in stopwords_ko]   # kk_tokens에 제거 완료된 토큰을 넣습니다
    
    
    ## 3. 영어 stopwords 제거
    # 위에서 미리 불용어 목록 얻음 (소문자화 된 점에 유의)
    k_e_tokens = [w for w in kk_tokens if w.lower() not in stopwords_en]
    # lower()를 이용해서 임시로 소문자화 한 뒤 필터링 한 단어(토큰)들을 k_e_tokens변수에 저장
    
    
    ## 4. 1글자 단어 제거(영어는 제외한다) - 1글자 stopwords 리스트 생성
    # 저장하지 않고 각 카테고리에서 그때그때 만들어 쓴다
    one_word = []  
    for i in k_e_tokens:
        if len(i) == 1:
            #print(i)
            one_word.append(i)  # 1글자 토큰을 one_word 리스트에 저장한다        
    u = set(one_word)  # 유니크 워드만 뽑기
    
    stopwords_one = []
    for i in u:
        if ord('a') <= ord(i.lower()) <= ord('z'):
            print(i)
        else:
            stopwords_one.append(i)
    print(stopwords_one) # 영어를 제외한 1글자 stopwords 리스트 stopwords_one

    final_tokens = [w for w in k_e_tokens if w not in stopwords_one]
    # 필터링 한 단어(토큰)들을 final_tokens변수에 저장
    
    
    ## 전부 소문자로 바꿔서 low_tokens변수에 저장하자
    low_tokens = []
    for i in range(len(final_tokens)):
        low_tokens.append(final_tokens[i].lower())
        

    ## stopwords 제거 완료한 빈도수 추출해보기
    fdistPlain_low = nltk.FreqDist(low_tokens)
    print(fdistPlain_low.most_common(30), '\n')  # 빈도수가 높은 토큰 30개 추출
# Out:
# # 6 번 카테고리의 크롤링한 채용공고의 개수 =  243
# 27104 -> 16454
# #postag를 이용해 불용어를 삭제한 tokens : {'동적', '일', '배우', '로도', 'ㄴ', '드리', '서로', '지니', '묻', '에게는', '아직', '쉽', '깊이있', '스럽', '좋', '폭넓', '망설이', '흩어지', '으시면', '간', '글쓰', '으로', '면', '과', '상하', '아낌없이', '서도', '수많', '그리고', '미치', '어서', '크', '이상', '달리', '부드럽', '와의', '계시', '다루', '혹은', '로서', '이', '다르', '처럼', '께', '말', '즐기', '모두', '다면', '대회', '어떤', '내', '며', '시ㄴ', '까다롭', '이나', '읽', '알리', '시ㄹ', '특별히', '시', '이내', '자', '거나', '과는', '쓰', '상관없이', '다만', '이루', '날카롭', '물', '따르', 'ㄴ데', '그', '및', '보', '알', '시는', '었던', '그외', '므로', '에게', '절', '리', '오', '실은', '에서의', '으시거나', '되', '준하', '익히', '입', '기이', '잘', '려고', '셨나', '몰리', '옳', '신나', '려는', '세', 'ㄴ가', '·', '도', '현재', '기대', '몸소', '강하', '어렵', '으면서', '관계없이', '부터', '통하', '까지', '겠어', '은', '바라', '별로', '매', '요하', '꼼꼼하', '다른', '재', '게', '주', '로서의', '에도', '언제나', '꿈꾸', '모든', '시면', '갖추', '조금', '있', '작', '책임지', '등등', '원활히', '하고', '멀', '서는', '졸', '만들', 'ㄴ다', '하', '라', '어', '타', '로는', '매일', '남다르', '고자', '깊', '보다는', '면서', '위하', '었습니다', '두', '더', '아아', '시거나', '는', '얼마나', '어도', '잡히', '으시어야', '단연', '정적', '가', '같', '보이', '에서', '높이', '끊임없이', '또한', '습니다', '에', '어야', '느끼', '들여다보', '들', '빌', '맞추', 'ㄴ단', '과도', '지만', '뜨겁', '려', '다', '이러하', '의', '부탁드리', '기', '서', '냐', '멈추', '적어도', '맞', '겠습니다', '원하', '정말', '개', '가장', '먼저', '석', '처음', '모집', '인하', '시고', '매우', '계속', '그렇', '갖', '나가', '으시ㄴ', '맡', '으로써', '아니', '로만', '적절히', '넓', '추후', '거리낌없이', '넘치', '리며', '동시에', '한하', '가르치', '으며', '일으키', '각', '더라도', '않', '피', '화하', '지', '으로서', '끊이', '아', '으로의', 'ㅂ니다', '만', '가지', 'ㅁ', '버리', '짜릿하', '나뉘', '짜', '어떻', '어서ㄴ', '특히', '연락드리', '라는', 'ㄹ', '독하', '바꾸', '서의', '비', '를', '새롭', '받', '항상', '밝', '와', '으시ㄹ', '시ㅁ', '열리', '예', '톡톡', '없', '함께하', '듣', '들이', '급', '요', '또는', '그치', '나타내', '뛰', '발맞추', '꾸준히', '이런', '빠르', '선', '즐겁', '단', '두렵', '직접', '높', '제대로', '다는', '깊이', '임하', '없이', '로', '아거나', '나누', '고', '사', '함께', '는지', '더어', '와도', '과의', '이끌', '꼭', '관하', '오히려', '보다', '불', '스스로', '잘하', '롭', '대', '싶', '나', '을', '대하', '이렇', '많', '찾', ';', '키우', '시키', '으면', '더욱', '로부터'}
# c
# R
# C
# Z
# W
# B
# ['리', '툴', '상', '중', '길', '수', '쪽', '파', '4', '끝', '성', '비', '글', '동', '전', '도', '별', '초', '간', '속', '딥', '3', '기', '곳', '깃', '2', '뿐', '체', '뭐', '재', '메', '주', '봇', '개', '외', '위', '석', '적', '말', '호', '미', '내', '관', '팀', '학', '투', '데', '부', '안', '평', '⅓', '후', '라', '+', '밖', '빅', '시', '삶', '1', '분', '줄', '두', '앱', '지', '정', '식', '한', '보', '님', '웹', '5', '바', '6', '문', '유', '소', '만']
# [('경험', 1016), ('개발', 565), ('이해', 226), ('python', 212), ('서비스', 208), ('사용', 191), ('운영', 175), ('관련', 140), ('경력', 137), ('활용', 130), ('기술', 121), ('aws', 119), ('능력', 114), ('데이터', 110), ('언어', 103), ('가능', 99), ('기반', 98), ('시스템', 92), ('지식', 91), ('java', 85), ('구축', 84), ('이용', 82), ('설계', 79), ('보유', 76), ('api', 72), ('코드', 71), ('환경', 71), ('테스트', 71), ('django', 69), ('경험자', 67)]
#
# # 7 번 카테고리의 크롤링한 채용공고의 개수 =  210
# 22715 -> 14090
# #postag를 이용해 불용어를 삭제한 tokens : {'리', '같', '짜', '오', '보이', '일', '배우', '에서의', '어떻', '되', '준하', '어서ㄴ', '특히', '에서', '접하', '연락드리', 'ㄴ', '드리', '더불', '지니', '익히', 'ㄹ', '끊임없이', '입', '기이', '에게는', '잘', '습니다', '려고', '에', '쉽', '어야', '셨나', '으니', '느끼', '옳', '끈질기', '좋', '서의', '들여다보', '에서만', '려는', '신나', '짧', '폭넓', '로써', 'ㄴ다는', '세', '비', '들', '를', '새롭', '받', '맞추', 'ㄴ가', '항상', '도', '변하', '현재', 'ㄴ단', '간', '글쓰', '지만', '기대', '으로', '와', '려', '다', '면', '과', '아낌없이', '시ㅁ', '셨다면', '쏟', '열리', '예', '의하', '빨리빨리', '강하', '으시다면', '히', '의', '없', '어렵', '으면서', '듣', '부탁드리', '들이', '어서', '기', '시기', '통하', '서', '부터', '크', '까지', '이상', '겠어', '요', '은', '돕', '바라', '또는', '펼치', '부드럽', '주되', '으로한', '와의', '매', '뛰', '꾸준히', '계시', '꼼꼼하', '맞', '다루', '아는', '다른', '모르', '이런', '빠르', '게', '혹은', '주', '선', '로서의', '즐겁', '에도', '매년', '만의', '원하', '만에', '로서', '정말', '개', '이', '어울리', '만나', '모든', '가장', '다르', '갖추', '먼저', '처럼', '석', '직접', '있', '높', '쌓', '께', '말', '책임지', '즐기', '다면', '인하', '능하', '셨거나', '깊이', '대회', '흐르', '내', '임하', '며', '매우', '원활히', '하고', '로', '아거나', '멀', '까지의', '서는', '시ㄴ', '갖', '총', '으시ㄴ', '안', '맡', '만들', '고', 'ㄴ다', '끄', '아니', '떠나', '사', '함께', '이나', '하', '적절히', '정하', '라', '어', '읽', '는지', '넓', '알리', '타', '시ㄹ', '아우르', '고자', '역하', '과의', '이내', '자', '이끌', '꼭', '거나', '쓰', '깊', '관하', '는다', '으며', '이루', '불', '각', '스스로', '잘하', '더라도', '면서', '위하', '물', '날카롭', '따르', '않', '피', '롭', '지', '화하', '끊이', 'ㄴ데', '그', '여러', '으로서', '도록', '아', '더', '헤치', '시거나', '대', '및', '는', '싶', '으시는', '얼마나', '보', '나', '어도', '가지', '걸치', '알', '을', '시는', '대하', '었던', '많', '찾', '그외', ';', '키우', '서와의', '늘', '으면', '시키', '이르', 'ㅂ니다', '에게', '반드시', '로부터', '만', 'ㅁ', '가'}
# R
# c
# C
# B
# ['리', '외', '툴', '상', '중', '1', '폭', '위', '수', '쪽', '석', '차', '분', '적', '속', '앞', '직', '딥', '3', '강', '호', '파', '미', '기', '4', '앱', '지', '량', '내', '팀', '학', '은', '투', '대', '한', '데', '으', '부', '끝', '터', '2', '–', '님', '뿐', '성', '웹', '글', '후', '메', '전', '주', '라', '문', '유', '처', '빅', '쉘', '소', '근', '시', '룰', '초', '개']
# [('경험', 786), ('데이터', 338), ('개발', 315), ('운영', 233), ('이해', 143), ('분석', 133), ('관련', 132), ('경력', 123), ('구축', 120), ('능력', 120), ('서비스', 119), ('활용', 113), ('python', 112), ('사용', 111), ('aws', 103), ('기반', 103), ('처리', 98), ('sql', 92), ('보유', 90), ('기술', 90), ('시스템', 89), ('경험자', 85), ('가능', 83), ('지식', 82), ('환경', 79), ('역량', 76), ('커뮤니케이션', 70), ('설계', 68), ('spark', 67), ('대용량', 65)]
#
# # 12 번 카테고리의 크롤링한 채용공고의 개수 =  144
# 16047 -> 9970
# #postag를 이용해 불용어를 삭제한 tokens : {'리', '같', '오', '보이', '일', '배우', '에서의', '으시거나', '어떻', '되', '준하', '어서ㄴ', '특히', '에서', '음', '연락드리', 'ㄴ', '드리', '지니', 'ㄹ', '독하', '기이', '에게는', '잘', '습니다', '려고', '에', '더하', '쉽', '셨나', '으니', '느끼', '스럽', '서의', '좋', '들여다보', '신나', '절대로', '비', '세', '들', '건', '를', '새롭', '받', '맞추', 'ㄴ가', '도', '변하', 'ㄴ단', '잦', '글쓰', '기대', '으로', '와', '려', '면', '과', '이러하', '시ㅁ', '살피', '예', '단순히', '빨리빨리', '강하', '의', '없', '어렵', '듣', '부탁드리', '어서', '기', '시기', '통하', '서', '까지', '이상', '요', '은', '돕', '적어도', '바라', '또는', '부드럽', '주되', '와의', '매', '뛰', '발맞추', '계시', '꼼꼼하', '맞', '든', '다루', '모르', '다른', '이런', '빠르', '게', '혹은', '주', '더더욱', '선', '즐겁', '단', '에도', '만의', '실제로', '원하', '로서', '개', '이', '어울리', '모든', '다르', '가장', '갖추', 'ㄹ지', '먼저', '틀리', '처럼', '석', '직접', '있', '높', '책임지', '즐기', '모두', '어느', '다면', '대회', '다는', '깊이', '어떤', '흐르', '시고', '내', '임하', '며', '라면', '원활히', '하고', '로', '멀', '서는', '시ㄴ', '갖', '총', '으시ㄴ', '맡', '만들', '고', '끄', '아니', '사', '이나', '함께', '하', '또', '정하', '예의바르', '라', '어', '읽', '겪', '타', '시ㄹ', '시', '고자', '과의', '자', '이끌', '꼭', '한하', '거나', '가르치', '쓰', '깊', '관하', '으며', '이루', '불', '스스로', '더라도', '날카롭', '위하', '물', '않', '따르', '피', '도록', '지', '화하', '으로서', 'ㄴ데', '그', '여러', '아', '더', '헤치', '시거나', '대', '및', '는', '싶', '보', '나', '어도', '가지', '걸치', '알', '을', '시는', '대하', '넘나들', '었던', '많', '찾', ';', '그외', '시키', '늘', '으나', '으면', 'ㅂ니다', '에게', '로부터', '만', 'ㅁ', '가'}
# R
# C
# B
# ['리', '외', '툴', '위', '1', '중', '수', '쪽', '석', '분', '적', '린', '앞', '딥', '3', '강', '호', '파', '기', '4', '지', '8', '내', '정', '팀', '학', '은', '#', '식', '대', '한', '데', '부', '끝', '터', '2', '뿐', '성', '⅓', '웹', '글', '5', '6', '주', '문', '유', '인', '명', '처', '택', '소', '추', '시', '개']
# [('경험', 447), ('데이터', 271), ('분석', 188), ('관련', 165), ('개발', 139), ('활용', 120), ('능력', 112), ('경력', 110), ('이해', 103), ('python', 86), ('보유', 80), ('운영', 78), ('사용', 77), ('머신러닝', 77), ('서비스', 74), ('기반', 71), ('지식', 65), ('가능', 63), ('sql', 57), ('역량', 57), ('통계', 55), ('우대', 53), ('모델링', 51), ('data', 51), ('커뮤니케이션', 50), ('분야', 49), ('aws', 49), ('r', 43), ('언어', 43), ('프로젝트', 43)]
#
# # 13 번 카테고리의 크롤링한 채용공고의 개수 =  143
# 14198 -> 9246
# #postag를 이용해 불용어를 삭제한 tokens : {'같', '짜', '오', '겠다는', '일', '실은', '배우', '에서의', '으시거나', '되', '준하', '어서ㄴ', '특히', '에서', '음', '연락드리', 'ㄴ', '드리', '지니', '익히', 'ㄹ', '끊임없이', '입', '기이', '에게는', '잘', '바꾸', '습니다', '에', '려고', '쉽', '으니', '느끼', '스럽', '옳', '좋', '로써', '비', '건', '들', '를', '새롭', '받', '도', 'ㄴ단', '서이', '글쓰', '밝', '와', '으로', '면', '과', '상하', '시ㅁ', '살피', '예', '단순히', '빨리빨리', '강하', '의', '없', '어렵', '듣', '부탁드리', '어서', '기', '시기', '통하', '서', '부터', '크', '까지', '이상', '은', '바라', '적어도', '또는', '그치', '으로한', '와의', '뛰', '발맞추', '계시', '꼼꼼하', '맞', '든', '다루', '모르', '다른', '빠르', '게', '혹은', '주', '선', '즐겁', '단', '만의', '실제로', '정말', '개', '이', '어울리', '만나', '모든', '가장', '갖추', '먼저', '석', '직접', '있', '높', '즐기', '모두', '어느', '대회', '다는', '어떤', '흐르', '시고', '내', '며', '매우', '원활히', '하고', '로', '멀', '까지의', '시ㄴ', '갖', '총', '맡', '으시ㄴ', '졸', '만들', '고', '끄', '아니', '사', '이나', '함께', '하', '정하', '예의바르', '라', '어', '읽', '겪', '타', '시ㄹ', '아우르', '시', '넘치', '고자', '과의', '자', '이끌', '동시에', '한하', '거나', '가르치', '쓰', '깊', '관하', '으며', '불', '이루', '각', '스스로', '더라도', '위하', '물', '않', '따르', '피', '롭', '지', '도록', '여러', 'ㄴ데', '그', '아', '더', '헤치', '시거나', '명확히', '대', '및', '는', '싶', '보', '나', '어도', '가지', '알', '을', '시는', '대하', '넘나들', '었던', '많', '찾', '시키', '으면', 'ㅂ니다', '에게', '로부터', '만', 'ㅁ', '가'}
# R
# c
# C
# W
# B
# ['리', '툴', '위', '외', '중', '삶', '1', '수', '쪽', '석', '분', '적', '줄', '직', '딥', '3', '강', '호', '미', '기', '두', '앱', '지', '내', '간', '정', '팀', '학', '요', '\u200b', '식', '대', '한', '데', '끝', '2', '평', '뿐', '성', '⅓', '웹', '글', '후', '바', '전', '주', '+', '문', '유', '빅', '쉘', '소', '도', '근', '시', '개']
# [('경험', 464), ('개발', 211), ('관련', 190), ('데이터', 159), ('분석', 116), ('python', 101), ('이해', 96), ('능력', 89), ('활용', 89), ('경력', 83), ('사용', 82), ('딥러닝', 81), ('머신러닝', 81), ('경험자', 67), ('분야', 66), ('learning', 63), ('기반', 62), ('tensorflow', 61), ('서비스', 60), ('논문', 55), ('기술', 54), ('언어', 54), ('구현', 49), ('지식', 48), ('알고리즘', 47), ('pytorch', 45), ('가능', 45), ('ml', 43), ('프로그래밍', 42), ('업무', 40)]
#
# # 15 번 카테고리의 크롤링한 채용공고의 개수 =  114
# 11365 -> 7207
# #postag를 이용해 불용어를 삭제한 tokens : {'리', '재미있', '같', '오', '배우', '에서의', '으시거나', '되', '준하', '어서ㄴ', '에서', '음', 'ㄴ', '서로', '지니', '익히', 'ㄹ', '끊임없이', '기이', '에게는', '잘', '습니다', '려고', '에', '쉽', '어야', '느끼', '스럽', '서의', '좋', '배', '려는', '폭넓', 'ㄴ다는', '비', '들', '를', '새롭', '항상', '도', 'ㄴ단', '간', '으로', '와', '다', '려', '면', '과', '상하', '아낌없이', '살피', '었는지', '열리', '예', '강하', '으시다면', '히', '의', '없', '어렵', '함께하', '어서', '기', '통하', '서', '까지', '이상', '은', '바라', '또는', '와의', '뛰', '발맞추', '꾸준히', '요하', '계시', '꼼꼼하', '맞', '다루', '빠르', '게', '혹은', '주', '선', '즐겁', '실제로', '로서', '개', '이', '만나', '모든', '갖추', '석', '직접', '있', '높', '즐기', '모두', '어느', '대회', '셨거나', '흐르', '시고', '내', '임하', '며', '원활히', '하고', '로', '아거나', '멀', '그렇', '시ㄴ', '갖', '총', '안', '으시ㄴ', '맡', '만들', '고', '아니', '사', '함께', '이나', '하', '예의바르', '라', '어', '읽', '겪', '타', '시ㄹ', '아우르', '시', '고자', '과의', '자', '이끌', '한하', '거나', '쓰', '깊', '으며', '각', '스스로', '면서', '위하', '물', '않', '피', '롭', '지', '여러', '화하', 'ㄴ데', '그', '아', '더', '대', '및', '는', '싶', '으시는', '왜', '보', '나', '어도', '가지', '걸치', '알', '을', '시는', '대하', '넘나들', '었던', '많', '찾', '시키', '늘', '으면', '이르', '서와의', 'ㅂ니다', '에게', '로부터', '만', 'ㅁ', '가'}
# R
# C
# W
# B
# ['리', '툴', '외', '위', '중', '1', '수', '속', '분', '적', '직', '딥', '3', '미', '두', '4', '내', '간', '팀', '학', '\u200b', '식', '대', '한', '데', '부', '끝', '2', '뿐', '성', '⅓', '웹', '전', '주', '+', '문', '처', '쉘', '소', '시', '개']
# [('경험', 375), ('데이터', 157), ('개발', 125), ('관련', 115), ('분석', 94), ('경력', 82), ('운영', 71), ('활용', 70), ('이해', 63), ('능력', 63), ('python', 60), ('기반', 59), ('사용', 51), ('서비스', 51), ('보유', 49), ('처리', 49), ('가능', 45), ('구축', 44), ('업무', 44), ('지식', 43), ('경험자', 41), ('딥러닝', 40), ('환경', 40), ('aws', 37), ('우대', 37), ('머신러닝', 36), ('시스템', 36), ('기술', 35), ('언어', 34), ('역량', 34)]
